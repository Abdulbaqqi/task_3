# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import seaborn as sb

# %%
#import os
#os.getcwd()

# %%
fifa_data = pd.read_csv('data.csv')
fifa_data
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
fifa = fifa_data.drop('Unnamed: 0', axis=1)
fifa
# Out:
#            ID                  Name  Age  \
# 0      158023              L. Messi   31
# 1       20801     Cristiano Ronaldo   33
# 2      190871             Neymar Jr   26
# 3      193080                De Gea   27
# 4      192985          K. De Bruyne   27
# 5      183277             E. Hazard   27
# 6      177003             L. Modrić   32
# 7      176580             L. Suárez   31
# 8      155862          Sergio Ramos   32
# 9      200389              J. Oblak   25
# 10     188545        R. Lewandowski   29
# 11     182521              T. Kroos   28
# 12     182493              D. Godín   32
# 13     168542           David Silva   32
# 14     215914              N. Kanté   27
# 15     211110             P. Dybala   24
# 16     202126               H. Kane   24
# 17     194765          A. Griezmann   27
# 18     192448         M. ter Stegen   26
# 19     192119           T. Courtois   26
# 20     189511       Sergio Busquets   29
# 21     179813             E. Cavani   31
# ...

# %%
fifa.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
def country(y):
    return fifa[fifa['Nationality'] == y]
country('Nigeria')
# Out:
#            ID             Name  Age  \
# 425    226790         W. Ndidi   21
# 789    213655         A. Iwobi   22
# 858    172962         V. Moses   27
# 1022   185195        O. Ighalo   29
# 1296   234045      H. Onyekuru   21
# 1531   229092          A. Umar   23
# 1550   216820         M. Simon   22
# 1615   188182       L. Balogun   30
# 1701   209984           M. Agu   25
# 1754   201818          A. Musa   25
# 1942   202934         O. Onazi   25
# 1946   225719     K. Iheanacho   21
# 2179   193337           J. Obi   27
# 2282   211048        O. Kayode   25
# 2382   237207          S. Kalu   20
# 2431   239015        E. Dennis   20
# 2535   234457         O. Etebo   22
# 2583   232693       C. Awaziem   21
# 2981   198554          A. Ujah   27
# 3007   213414  W. Troost-Ekong   24
# 3015   222634       I. Success   22
# 3178   226289          U. Agbo   22
# 3239   207624        K. Omeruo   24
# 3391   227642     S. Adegbenro   22
# 3533   219496             Simy   26
# ...

# %%
fifa.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of            ID                  Name  Age  \
# 0      158023              L. Messi   31
# 1       20801     Cristiano Ronaldo   33
# 2      190871             Neymar Jr   26
# 3      193080                De Gea   27
# 4      192985          K. De Bruyne   27
# 5      183277             E. Hazard   27
# 6      177003             L. Modrić   32
# 7      176580             L. Suárez   31
# 8      155862          Sergio Ramos   32
# 9      200389              J. Oblak   25
# 10     188545        R. Lewandowski   29
# 11     182521              T. Kroos   28
# 12     182493              D. Godín   32
# 13     168542           David Silva   32
# 14     215914              N. Kanté   27
# 15     211110             P. Dybala   24
# 16     202126               H. Kane   24
# 17     194765          A. Griezmann   27
# 18     192448         M. ter Stegen   26
# 19     192119           T. Courtois   26
# 20     189511       Sergio Busquets   29
# ...

# %%
fifa.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   18207.000000  18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299   1597.809908
# std     29965.244204      4.669943      6.908930      6.136496    272.586016
# min        16.000000     16.000000     46.000000     48.000000    731.000000
# 25%    200315.500000     21.000000     62.000000     67.000000   1457.000000
# 50%    221759.000000     25.000000     66.000000     71.000000   1635.000000
# 75%    236529.500000     28.000000     71.000000     75.000000   1787.000000
# max    246620.000000     45.000000     94.000000     95.000000   2346.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# ...

# %%
nat = data[['Name','Nationality','Club','Wage', 'Preferred Foot']]
nat.head()
# Out:
#                 Name Nationality                 Club   Wage Preferred Foot
# 0           L. Messi   Argentina         FC Barcelona  €565K           Left
# 1  Cristiano Ronaldo    Portugal             Juventus  €405K          Right
# 2          Neymar Jr      Brazil  Paris Saint-Germain  €290K          Right
# 3             De Gea       Spain    Manchester United  €260K          Right
# 4       K. De Bruyne     Belgium      Manchester City  €355K          Right

# %%
plt.figure(figsize=(10,6))
sb.countplot(x='Preferred Foot', data=data)
plt.title('Preferred Foot')
# Out:
# Text(0.5,1,'Preferred Foot')

# %%
fifa['Joined'].head(10)
# Out:
# 0     Jul 1, 2004
# 1    Jul 10, 2018
# 2     Aug 3, 2017
# 3     Jul 1, 2011
# 4    Aug 30, 2015
# 5     Jul 1, 2012
# 6     Aug 1, 2012
# 7    Jul 11, 2014
# 8     Aug 1, 2005
# 9    Jul 16, 2014
# Name: Joined, dtype: object

# %%
youngest_players = fifa.sort_values('Age', ascending = True )
youngest_players[['Name', 'Age', 'Nationality', 'Club']].head(10)
# Out:
#                  Name  Age          Nationality             Club
# 18206       G. Nugent   16              England  Tranmere Rovers
# 17743       J. Olstad   16               Norway  Sarpsborg 08 FF
# 13293     H. Massengo   16               France        AS Monaco
# 16081     J. Italiano   16            Australia      Perth Glory
# 18166        N. Ayéva   16               Sweden        Örebro SK
# 17712        K. Broda   16               Poland     Wisła Kraków
# 17354     L. D'Arrigo   16            Australia  Adelaide United
# 13567  Y. Verschaeren   16              Belgium   RSC Anderlecht
# 16927       B. Nygren   16               Sweden     IFK Göteborg
# 18018     B. O'Gorman   16  Republic of Ireland   Bray Wanderers

# %%
eldest_play = fifa.sort_values('Age', ascending = False )
eldest_play[['Name', 'Age', 'Nationality', 'Club']].head(10)
# Out:
#                 Name  Age        Nationality                          Club
# 4741        O. Pérez   45             Mexico                       Pachuca
# 18183  K. Pilkington   44            England              Cambridge United
# 17726      T. Warner   44  Trinidad & Tobago            Accrington Stanley
# 10545    S. Narazaki   42              Japan                Nagoya Grampus
# 7225        C. Muñoz   41          Argentina  CD Universidad de Concepción
# 1120       J. Villar   41           Paraguay                           NaN
# 12192   H. Sulaimani   41       Saudi Arabia                     Ohod Club
# 15426       M. Tyler   41            England           Peterborough United
# 4228        B. Nivet   41             France                  ESTAC Troyes
# 10356       F. Kippe   40             Norway                 Lillestrøm SK

# %%
data[data['Preferred Foot']=='Right'][['Name', 'Age','Preferred Foot', 'Wage', 'Club', 'Nationality']].head(5)
# Out:
#                 Name  Age Preferred Foot   Wage                 Club  \
# 1  Cristiano Ronaldo   33          Right  €405K             Juventus
# 2          Neymar Jr   26          Right  €290K  Paris Saint-Germain
# 3             De Gea   27          Right  €260K    Manchester United
# 4       K. De Bruyne   27          Right  €355K      Manchester City
# 5          E. Hazard   27          Right  €340K              Chelsea
#
#   Nationality
# 1    Portugal
# 2      Brazil
# 3       Spain
# 4     Belgium
# 5     Belgium

# %%
data[data['Preferred Foot']=='Left'][['Name', 'Age','Preferred Foot', 'Wage', 'Club', 'Nationality']].head(5)
# Out:
#             Name  Age Preferred Foot   Wage             Club Nationality
# 0       L. Messi   31           Left  €565K     FC Barcelona   Argentina
# 13   David Silva   32           Left  €285K  Manchester City       Spain
# 15     P. Dybala   24           Left  €205K         Juventus   Argentina
# 17  A. Griezmann   27           Left  €145K  Atlético Madrid      France
# 19   T. Courtois   26           Left  €240K      Real Madrid     Belgium

# %%
plt.figure(figsize=(10,6))
sb.countplot(x='Height', data=data)
plt.title('Height')
# Out:
# Text(0.5,1,'Height')
